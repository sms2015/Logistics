# %% [markdown]
# # Using Predictive Analytics to Predict Delays in Maritime Container Shipping

# %%
# %matplotlib inline

# %% [markdown]
# **Import Libraries**

# %%
import csv
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

import pylab 
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

#http://pythondata.com/dask-large-csv-python/
#import dask.dataframe as dd
 
#from collections import Counter
#from patsy import dmatrices
#import statsmodels.api as sm

#https://www.dataquest.io/blog/pandas-big-data/

# %% [markdown]
# **Read in file**

# %%
df = pd.read_pickle('2014_data.pkl')

# %%
#check that all rows imported
df.shape
# Out:
# (10816209, 24)

# %%
#check datatypes
df.dtypes
# Out:
# identifier                             uint64
# trade_update_date              datetime64[ns]
# run_date                       datetime64[ns]
# vessel_name                          category
# port_of_unlading                     category
# estimated_arrival_date         datetime64[ns]
# foreign_port_of_lading               category
# record_status_indicator              category
# place_of_receipt                     category
# port_of_destination                  category
# foreign_port_of_destination          category
# actual_arrival_date            datetime64[ns]
# consignee_name                       category
# shipper_party_name                   category
# container_number                     category
# description_sequence_number            uint64
# piece_count                            uint64
# description_text                     category
# carrier                              category
# day_of_week_est                         uint8
# day_of_week_act                         uint8
# month_est                               uint8
# month_act                               uint8
# delay_days                              int16
# dtype: object

# %%
df.head()
# Out:
#       identifier trade_update_date   run_date    vessel_name  \
# 0  2014082158845        2014-07-30 2014-08-21  HYUNDAI FORCE
# 1  2014082158905        2014-07-30 2014-08-21  HYUNDAI FORCE
# 2  2014082158905        2014-07-30 2014-08-21  HYUNDAI FORCE
# 3  2014082158905        2014-07-30 2014-08-21  HYUNDAI FORCE
# 4  2014082158983        2014-08-06 2014-08-21  OOCL SHENZHEN
#
#          port_of_unlading estimated_arrival_date    foreign_port_of_lading  \
# 0     Seattle, Washington             2014-08-14         Pusan,South Korea
# 1     Seattle, Washington             2014-08-14         Pusan,South Korea
# 2     Seattle, Washington             2014-08-14         Pusan,South Korea
# 3     Seattle, Washington             2014-08-14         Pusan,South Korea
# 4  Long Beach, California             2014-08-19  Yantian,China (Mainland)
#
#   record_status_indicator place_of_receipt port_of_destination     ...      \
# 0                     New      XINGANG, PC                 NaN     ...
# 1                     New      XINGANG, PC                 NaN     ...
# 2                     New      XINGANG, PC                 NaN     ...
# 3                     New      XINGANG, PC                 NaN     ...
# 4                     New    YANTIAN,CHINA                 NaN     ...
#
#   container_number description_sequence_number piece_count  \
# 0      TGHU8036820                           1        7881
# 1      APZU3172532                           1          80
# 2      APZU3599329                           1          80
# 3      TRLU3176120                           1          80
# 4      OOLU1064780                           1         498
#
#                                     description_text  carrier  \
# 0  IKEA HOME FURNISHING PRODUCTS TARIFF NUMBER 44...  HYUNDAI
# 1  KLA-GARD PACKED ON 60 PALLETS -DRILLING MUD AD...  HYUNDAI
# 2  KLA-GARD PACKED ON 60 PALLETS -DRILLING MUD AD...  HYUNDAI
# 3  KLA-GARD PACKED ON 60 PALLETS -DRILLING MUD AD...  HYUNDAI
# 4  P.O.NO.050803/050938/051058/051197/051345/051 ...     OOCL
#
#    day_of_week_est  day_of_week_act month_est month_act  delay_days
# 0                3                1         8         8           5
# 1                3                1         8         8           5
# 2                3                1         8         8           5
# 3                3                1         8         8           5
# 4                1                2         8         8           1
#
# [5 rows x 24 columns]

# %%
list(df)
# Out:
# ['identifier',
#  'trade_update_date',
#  'run_date',
#  'vessel_name',
#  'port_of_unlading',
#  'estimated_arrival_date',
#  'foreign_port_of_lading',
#  'record_status_indicator',
#  'place_of_receipt',
#  'port_of_destination',
#  'foreign_port_of_destination',
#  'actual_arrival_date',
#  'consignee_name',
#  'shipper_party_name',
#  'container_number',
#  'description_sequence_number',
#  'piece_count',
#  'description_text',
#  'carrier',
#  'day_of_week_est',
#  'day_of_week_act',
#  'month_est',
#  'month_act',
#  'delay_days']

# %% [markdown]
# ** Get all vessels for the top West and East Coast U.S. ports **
# 'Los Angeles, California',
# 'New York/Newark Area, Newark, New Jersey' & 'New York, New York'

# %%
#set up a data frame for each port
df_LA = df[df.port_of_unlading == 'Los Angeles, California']

# %%
#get the list of all vessels that use these ports
vessels_LA = df_LA.vessel_name.unique()
len(vessels_LA)
# Out:
# (1640, 1255)

# %% [markdown]
# ** Get all observations for these vessels for vessel voyages that surved these ports **
# -where the date is within 30 days of any unlading date at these ports

# %%
#Get all unladings at the port by vessel_name and estimated_arrival_date
unl_dates_LA = df_LA[['vessel_name','estimated_arrival_date']].drop_duplicates()
print len(unl_dates_LA)
unl_dates_LA.head(10)
# Out:
# 17635
#           vessel_name estimated_arrival_date
# 7       COSCO HARMONY             2014-08-19
# 66       YM MUTUALITY             2014-08-19
# 67       YM MUTUALITY             2014-08-18
# 69   SEA-LAND CHARGER             2014-07-28
# 74        CSCL SUMMER             2014-08-17
# 84   MOL CONTRIBUTION             2014-08-18
# 87          NYK TERRA             2014-08-18
# 111      YM MUTUALITY             2014-08-20
# 139  MAERSK WOLFSBURG             2014-08-20
# 147     GUSTAV MAERSK             2014-08-17

# %%
#identify the range d (=/- days around the estimated arrival dates)
d = 15
#add a column for each date
cols = []
for i in range(-d,d+1):
    colname = 'col' + str(i)
    unl_dates_LA[colname] = unl_dates_LA.estimated_arrival_date + timedelta(days=i)
    cols.append(colname)

#drop the estimated_arrival_date column
unl_dates_LA.drop('estimated_arrival_date', axis = 1, inplace = True)

# %%
#view the data
print cols
unl_dates_LA.head()
# Out:
# ['col-15', 'col-14', 'col-13', 'col-12', 'col-11', 'col-10', 'col-9', 'col-8', 'col-7', 'col-6', 'col-5', 'col-4', 'col-3', 'col-2', 'col-1', 'col0', 'col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7', 'col8', 'col9', 'col10', 'col11', 'col12', 'col13', 'col14', 'col15']
#          vessel_name     col-15     col-14     col-13     col-12     col-11  \
# 7      COSCO HARMONY 2014-08-04 2014-08-05 2014-08-06 2014-08-07 2014-08-08
# 66      YM MUTUALITY 2014-08-04 2014-08-05 2014-08-06 2014-08-07 2014-08-08
# 67      YM MUTUALITY 2014-08-03 2014-08-04 2014-08-05 2014-08-06 2014-08-07
# 69  SEA-LAND CHARGER 2014-07-13 2014-07-14 2014-07-15 2014-07-16 2014-07-17
# 74       CSCL SUMMER 2014-08-02 2014-08-03 2014-08-04 2014-08-05 2014-08-06
#
#        col-10      col-9      col-8      col-7    ...           col6  \
# 7  2014-08-09 2014-08-10 2014-08-11 2014-08-12    ...     2014-08-25
# 66 2014-08-09 2014-08-10 2014-08-11 2014-08-12    ...     2014-08-25
# 67 2014-08-08 2014-08-09 2014-08-10 2014-08-11    ...     2014-08-24
# 69 2014-07-18 2014-07-19 2014-07-20 2014-07-21    ...     2014-08-03
# 74 2014-08-07 2014-08-08 2014-08-09 2014-08-10    ...     2014-08-23
#
#          col7       col8       col9      col10      col11      col12  \
# 7  2014-08-26 2014-08-27 2014-08-28 2014-08-29 2014-08-30 2014-08-31
# 66 2014-08-26 2014-08-27 2014-08-28 2014-08-29 2014-08-30 2014-08-31
# 67 2014-08-25 2014-08-26 2014-08-27 2014-08-28 2014-08-29 2014-08-30
# 69 2014-08-04 2014-08-05 2014-08-06 2014-08-07 2014-08-08 2014-08-09
# 74 2014-08-24 2014-08-25 2014-08-26 2014-08-27 2014-08-28 2014-08-29
#
#         col13      col14      col15
# 7  2014-09-01 2014-09-02 2014-09-03
# 66 2014-09-01 2014-09-02 2014-09-03
# 67 2014-08-31 2014-09-01 2014-09-02
# 69 2014-08-10 2014-08-11 2014-08-12
# 74 2014-08-30 2014-08-31 2014-09-01
#
# [5 rows x 32 columns]

# %%
#reshape the data to get columns as rows (name the new column estimated arrival date for next step in comparing to original file)
unl_flag_LA = pd.melt(unl_dates_LA, id_vars=['vessel_name'], value_vars=cols,
        var_name='colname', value_name='estimated_arrival_date')

# %%
#view the data
print unl_flag_LA.shape
unl_flag_LA.head()
# Out:
# (546685, 3)
#         vessel_name colname estimated_arrival_date
# 0     COSCO HARMONY  col-15             2014-08-04
# 1      YM MUTUALITY  col-15             2014-08-04
# 2      YM MUTUALITY  col-15             2014-08-03
# 3  SEA-LAND CHARGER  col-15             2014-07-13
# 4       CSCL SUMMER  col-15             2014-08-02

# %%
#remove duplicates
unl_flag_LA = unl_flag_LA[['vessel_name','estimated_arrival_date']].drop_duplicates()
unl_flag_LA.shape
# Out:
# (155116, 2)

# %%
#get all observations for the vessels (at any port of unlading) for vessels that use these ports 
#match the vessel_name and the date if it is within d days of an unlading observation at these ports
#add a flag to the original dataframe
df_flag_LA = pd.merge(df, unl_flag_LA, on=['vessel_name','estimated_arrival_date'], how='left', indicator='flag')

# %%
df_flag_LA.head()
# Out:
#       identifier trade_update_date   run_date    vessel_name  \
# 0  2014082158845        2014-07-30 2014-08-21  HYUNDAI FORCE
# 1  2014082158905        2014-07-30 2014-08-21  HYUNDAI FORCE
# 2  2014082158905        2014-07-30 2014-08-21  HYUNDAI FORCE
# 3  2014082158905        2014-07-30 2014-08-21  HYUNDAI FORCE
# 4  2014082158983        2014-08-06 2014-08-21  OOCL SHENZHEN
#
#          port_of_unlading estimated_arrival_date    foreign_port_of_lading  \
# 0     Seattle, Washington             2014-08-14         Pusan,South Korea
# 1     Seattle, Washington             2014-08-14         Pusan,South Korea
# 2     Seattle, Washington             2014-08-14         Pusan,South Korea
# 3     Seattle, Washington             2014-08-14         Pusan,South Korea
# 4  Long Beach, California             2014-08-19  Yantian,China (Mainland)
#
#   record_status_indicator place_of_receipt port_of_destination    ...      \
# 0                     New      XINGANG, PC                 NaN    ...
# 1                     New      XINGANG, PC                 NaN    ...
# 2                     New      XINGANG, PC                 NaN    ...
# 3                     New      XINGANG, PC                 NaN    ...
# 4                     New    YANTIAN,CHINA                 NaN    ...
#
#   description_sequence_number piece_count  \
# 0                           1        7881
# 1                           1          80
# 2                           1          80
# 3                           1          80
# 4                           1         498
#
#                                     description_text  carrier day_of_week_est  \
# 0  IKEA HOME FURNISHING PRODUCTS TARIFF NUMBER 44...  HYUNDAI               3
# 1  KLA-GARD PACKED ON 60 PALLETS -DRILLING MUD AD...  HYUNDAI               3
# 2  KLA-GARD PACKED ON 60 PALLETS -DRILLING MUD AD...  HYUNDAI               3
# 3  KLA-GARD PACKED ON 60 PALLETS -DRILLING MUD AD...  HYUNDAI               3
# 4  P.O.NO.050803/050938/051058/051197/051345/051 ...     OOCL               1
#
#    day_of_week_act  month_est month_act delay_days       flag
# 0                1          8         8          5  left_only
# 1                1          8         8          5  left_only
# 2                1          8         8          5  left_only
# 3                1          8         8          5  left_only
# 4                2          8         8          1       both
#
# [5 rows x 25 columns]

# %%
#get just the observation where the flag = both
df_v_LA = df_flag_LA[df_flag_LA.flag == 'both']
df_v_LA.shape
# Out:
# (5126351, 25)

# %% [markdown]
# ** Identify Vessel Voyages **
# group vessels by dates within d days of each other - assume longer than d days is a different voyage

# %%
#sort by vessel,then by estimated arrival date, then by port_of_unlading
df_v_LA = df_v_LA.sort_values(['vessel_name','estimated_arrival_date','port_of_unlading'])
df_v_LA.head(10)
# Out:
#              identifier trade_update_date   run_date     vessel_name  \
# 7154900   2014081953955        2014-07-31 2014-08-19   GUSTAV MAERSK
# 7915738   2014060342997        2014-05-15 2014-06-03     XIN YA ZHOU
# 10172071  2014060343078        2014-05-15 2014-06-03     XIN YA ZHOU
# 1843760    201404011097        2014-02-07 2014-04-01            1406
# 138311    2014030426213        2014-02-04 2014-03-04    610140003896
# 4184140   2014080128972        2014-07-10 2014-08-01         9074389
# 7815745   2014012138431        2014-01-03 2014-01-21         9074391
# 1988280   2014092437176        2014-09-05 2014-09-24         9074547
# 4373677   2014040245889        2014-03-19 2014-04-02         9077276
# 9005066   2014040245882        2014-03-19 2014-04-02         9077276
#
#                  port_of_unlading estimated_arrival_date  \
# 7154900   Los Angeles, California             2014-08-17
# 7915738   Los Angeles, California             2014-05-30
# 10172071  Los Angeles, California             2014-05-30
# 1843760   Los Angeles, California             2014-03-17
# 138311    Los Angeles, California             2014-02-27
# 4184140   Los Angeles, California             2014-07-29
# 7815745   Los Angeles, California             2014-01-20
# 1988280   Los Angeles, California             2014-09-23
# 4373677   Los Angeles, California             2014-03-21
# 9005066   Los Angeles, California             2014-03-21
#
#             foreign_port_of_lading record_status_indicator  place_of_receipt  \
# 7154900   Yantian,China (Mainland)                     New           YANTIAN
# 7915738   Ningpo ,China (Mainland)                     New            NINGBO
# 10172071  Ningpo ,China (Mainland)                     New            NINGBO
# 1843760      Kwangyang,South Korea                     New  KARACHI-PAKISTAN
# 138311         Singapore,Singapore                     New           JAKARTA
# 4184140   Xingang,China (Mainland)                     New           TIANJIN
# 7815745          Pusan,South Korea                     New           XINGANG
# 1988280   Xingang,China (Mainland)                     New           TIANJIN
# 4373677             Yokohama,Japan                     New          YOKOHAMA
# 9005066               Tokyo ,Japan                     New             TOKYO
#
#          port_of_destination  ...  description_sequence_number piece_count  \
# 7154900                  NaN  ...                            1         224
# 7915738                  NaN  ...                            1           4
# 10172071                 NaN  ...                            1          10
# 1843760                  NaN  ...                            1         772
# 138311                   NaN  ...                            1         190
# 4184140                  NaN  ...                            1          39
# 7815745                  NaN  ...                            1         156
# 1988280                  NaN  ...                            1           4
# 4373677                  NaN  ...                            1           3
# 9005066                  NaN  ...                            1           1
#
#                                            description_text       carrier  \
# 7154900                                     RATCHET RATCHET        GUSTAV
# 7915738                                          ROLLER . .           XIN
# 10172071                            RADIAL BALL BEARING . .           XIN
# 1843760                                       KNITTED SOCKS          1406
# 138311                    COMPONENT FOR HYDRAULIC EXCAVATOR  610140003896
# 4184140   AIR MOVING DEVICE FMC#8400-00-0482-0001 39CTNS...       9074389
# 7815745                                           GLASSWARE       9074391
# 1988280                                   AC TRACTION MOTOR       9074547
# 4373677                             WELDER HS CODE: 8515.21       9077276
# 9005066   "SEIKO" BRAND INDUSTRIAL SEWING MACHINE HS COD...       9077276
#
#          day_of_week_est  day_of_week_act  month_est month_act delay_days  \
# 7154900                6                0          8         8          1
# 7915738                4                6          5         6          2
# 10172071               4                6          5         6          2
# 1843760                0                0          3         3         14
# 138311                 3                5          2         3          2
# 4184140                1                3          7         7          2
# 7815745                0                0          1         1          0
# 1988280                1                1          9         9          0
# 4373677                4                1          3         4         11
# 9005066                4                1          3         4         11
#
#           flag
# 7154900   both
# 7915738   both
# 10172071  both
# 1843760   both
# 138311    both
# 4184140   both
# 7815745   both
# 1988280   both
# 4373677   both
# 9005066   both
#
# [10 rows x 25 columns]

# %%
#groupby vessel_name and shift the estimated_arrival_date down one row to compare current to prior
df_v_LA['prior_est_arr_date'] = df_v_LA.groupby(['vessel_name'])['estimated_arrival_date'].shift()

# %%
df_v_LA.head()
# Out:
#              identifier trade_update_date   run_date     vessel_name  \
# 7154900   2014081953955        2014-07-31 2014-08-19   GUSTAV MAERSK
# 7915738   2014060342997        2014-05-15 2014-06-03     XIN YA ZHOU
# 10172071  2014060343078        2014-05-15 2014-06-03     XIN YA ZHOU
# 1843760    201404011097        2014-02-07 2014-04-01            1406
# 138311    2014030426213        2014-02-04 2014-03-04    610140003896
#
#                  port_of_unlading estimated_arrival_date  \
# 7154900   Los Angeles, California             2014-08-17
# 7915738   Los Angeles, California             2014-05-30
# 10172071  Los Angeles, California             2014-05-30
# 1843760   Los Angeles, California             2014-03-17
# 138311    Los Angeles, California             2014-02-27
#
#             foreign_port_of_lading record_status_indicator  place_of_receipt  \
# 7154900   Yantian,China (Mainland)                     New           YANTIAN
# 7915738   Ningpo ,China (Mainland)                     New            NINGBO
# 10172071  Ningpo ,China (Mainland)                     New            NINGBO
# 1843760      Kwangyang,South Korea                     New  KARACHI-PAKISTAN
# 138311         Singapore,Singapore                     New           JAKARTA
#
#          port_of_destination         ...         piece_count  \
# 7154900                  NaN         ...                 224
# 7915738                  NaN         ...                   4
# 10172071                 NaN         ...                  10
# 1843760                  NaN         ...                 772
# 138311                   NaN         ...                 190
#
#                            description_text       carrier day_of_week_est  \
# 7154900                     RATCHET RATCHET        GUSTAV               6
# 7915738                          ROLLER . .           XIN               4
# 10172071            RADIAL BALL BEARING . .           XIN               4
# 1843760                       KNITTED SOCKS          1406               0
# 138311    COMPONENT FOR HYDRAULIC EXCAVATOR  610140003896               3
#
#          day_of_week_act  month_est  month_act delay_days  flag  \
# 7154900                0          8          8          1  both
# 7915738                6          5          6          2  both
# 10172071               6          5          6          2  both
# 1843760                0          3          3         14  both
# 138311                 5          2          3          2  both
#
#           prior_est_arr_date
# 7154900                  NaT
# 7915738                  NaT
# 10172071          2014-05-30
# 1843760                  NaT
# 138311                   NaT
#
# [5 rows x 26 columns]

# %%
df_v_LA.prior_est_arr_date.values[0] == np.datetime64('nat')
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: In the future, 'NAT == x' and 'x == NAT' will always be False.
#   if __name__ == '__main__':
# True

# %%
#check if the prior date is within d days of the prior estimated arrival date
df_v_LA['same_as_prior'] = df_v_LA.estimated_arrival_date <= df_v_LA.prior_est_arr_date + timedelta(days=d)

# %%
#for all false in same as prior enter 1 otherwise enter 0, then implement a running sum to get the voyage numbers
df_v_LA['new_voyage'] = ~df_v_LA.same_as_prior * 1

# %%
#df_v_LA.new_voyage.cumsum()
#df.groupby('id')['val'].cumsum()
df_v_LA['voyage'] = df_v_LA.groupby('vessel_name')['new_voyage'].cumsum()

# %%
df_v_LA.head(50)
# Out:
#              identifier trade_update_date   run_date     vessel_name  \
# 7154900   2014081953955        2014-07-31 2014-08-19   GUSTAV MAERSK
# 7915738   2014060342997        2014-05-15 2014-06-03     XIN YA ZHOU
# 10172071  2014060343078        2014-05-15 2014-06-03     XIN YA ZHOU
# 1843760    201404011097        2014-02-07 2014-04-01            1406
# 138311    2014030426213        2014-02-04 2014-03-04    610140003896
# 4184140   2014080128972        2014-07-10 2014-08-01         9074389
# 7815745   2014012138431        2014-01-03 2014-01-21         9074391
# 1988280   2014092437176        2014-09-05 2014-09-24         9074547
# 4373677   2014040245889        2014-03-19 2014-04-02         9077276
# 9005066   2014040245882        2014-03-19 2014-04-02         9077276
# 7593917   2014040245892        2014-03-19 2014-04-02         9077276
# 724172    2014040245893        2014-03-19 2014-04-02         9077276
# 9225078   2014011818497        2013-12-23 2014-01-18         9077458
# 1056425              2014-06-19                     Singapore,Singapore
# 9340053              2014-06-23                   Laem Chabang,Thailand
# 9340054              2014-06-23                   Laem Chabang,Thailand
# 6948524              2014-12-04                     Singapore,Singapore
# 8683233              2014-02-14                    Yarraville,Australia
# 9009749              2014-04-05                        Sydney,Australia
#
#          record_status_indicator  place_of_receipt port_of_destination  \
# 7154900                      New           YANTIAN                 NaN
# 7915738                      New            NINGBO                 NaN
# 10172071                     New            NINGBO                 NaN
# 1843760                      New  KARACHI-PAKISTAN                 NaN
# 138311                       New           JAKARTA                 NaN
# 4184140                      New           TIANJIN                 NaN
# 7815745                      New           XINGANG                 NaN
# 1988280                      New           TIANJIN                 NaN
# 4373677                      New          YOKOHAMA                 NaN
# 9005066                      New             TOKYO                 NaN
# 7593917                      New          YOKOHAMA                 NaN
# 724172                       New          YOKOHAMA                 NaN
# 9225078                      New        PORT KLANG                 NaN
# 7210256                      New        LATKRABANG                 NaN
# 5311476                      New            SYDNEY                 NaN
# 487517                       New      SINGAPORE SG                 NaN
# 487516                       New      SINGAPORE SG                 NaN
# 487515                       New      SINGAPORE SG                 NaN
# 487518                       New      SINGAPORE SG                 NaN
# 487512                       New      SINGAPORE SG                 NaN
# 487513                       New      SINGAPORE SG                 NaN
# 9324781                      New             TOKYO                 NaN
# 4414697                      New             TOKYO                 NaN
# 8753189                      New           QINGDAO                 NaN
# 4246557                      New         HYDERABAD                 NaN
# 596682                       New         SINGAPORE                 NaN
# 596683                       New         SINGAPORE                 NaN
# 596681                       New         SINGAPORE                 NaN
# 596680                       New         SINGAPORE                 NaN
# 596684                       New         SINGAPORE                 NaN
# 596685                       New         SINGAPORE                 NaN
# 1891193                      New       HO CHI MINH                 NaN
# 5384165                      New         SINGAPORE                 NaN
# 3586524                      New       PORT KELANG                 NaN
# 7318246                      New           HAMBURG                 NaN
# 6598028                      New      NAGOYA,JAPAN                 NaN
# 10741215                     New         SINGAPORE                 NaN
# 205066                       New          SHENZHEN                 NaN
# 2743704                      New          SHENZHEN                 NaN
# 8651188                      New  LAEM CHABANG, TH                 NaN
# 4734684                  Amended       BANGKOK, TH                 NaN
# 7009106                      New   LAT KRABANG, TH                 NaN
# 3013318                      New       NHAVA SHEVA                 NaN
# 3685662                      New      GRETE MAERSK                 NaN
# 1056425                      New            MUMBAI                 NaN
# 9340053                      New      LAEM CHABANG                 NaN
# 9340054                      New      LAEM CHABANG                 NaN
# 6948524                      New            MUMBAI                 NaN
# 8683233                      New            SYDNEY                 NaN
# 9009749                      New            SYDNEY                 NaN
#
#            ...   day_of_week_est day_of_week_act month_est month_act  \
# 7154900    ...                 6               0         8         8
# 7915738    ...                 4               6         5         6
# 10172071   ...                 4               6         5         6
# 1843760    ...                 0               0         3         3
# 138311     ...                 3               5         2         3
# 4184140    ...                 1               3         7         7
# 7815745    ...                 0               0         1         1
# 1988280    ...                 1               1         9         9
# 4373677    ...                 4               1         3         4
# 9005066    ...                 4               1         3         4
# 7593917    ...                 4               1         3         4
# 724172     ...                 4               1         3         4
# 9225078    ...                 3               4         1         1
# 7210256    ...                 0               1        11        11
# 5311476    ...                 6               6         2         2
# 487517     ...                 4               0         5         6
# 487516     ...                 4               0         5         6
# 487515     ...                 4               0         5         6
# 487518     ...                 4               0         5         6
# 487512     ...                 4               0         5         6
# 487513     ...                 4               0         5         6
# 9324781    ...                 0               0         6         6
# 4414697    ...                 0               0         6         6
# 8753189    ...                 0               0         6         6
# 4246557    ...                 0               0        10        10
# 596682     ...                 3               4        10        10
# 596683     ...                 3               4        10        10
# 596681     ...                 3               4        10        10
# 596680     ...                 3               4        10        10
# 596684     ...                 3               4        10        10
# 596685     ...                 3               4        10        10
# 1891193    ...                 5               1         5         6
# 5384165    ...                 5               0         5         6
# 3586524    ...                 6               1         6         6
# 7318246    ...                 1               4         4         4
# 6598028    ...                 1               5         9         9
# 10741215   ...                 2               2         6         6
# 205066     ...                 2               4         6         6
# 2743704    ...                 2               4         6         6
# 8651188    ...                 3               4         1         1
# 4734684    ...                 3               4         1         1
# 7009106    ...                 3               4         2         2
# 3013318    ...                 3               3         5         5
# 3685662    ...                 2               0         9         9
# 1056425    ...                 3               3         6         6
# 9340053    ...                 0               1         6         6
# 9340054    ...                 0               1         6         6
# 6948524    ...                 3               1        12        12
# 8683233    ...                 4               5         2         2
# 9009749    ...                 5               0         4         4
#
#          delay_days  flag  prior_est_arr_date same_as_prior new_voyage  voyage
# 7154900           1  both                 NaT         False          1       1
# 7915738           2  both                 NaT         False          1       1
# 10172071          2  both          2014-05-30          True          0       1
# 1843760          14  both                 NaT         False          1       1
# 138311            2  both                 NaT         False          1       1
# 4184140           2  both                 NaT         False          1       1
# 7815745           0  both                 NaT         False          1       1
# 1988280           0  both                 NaT         False          1       1
# 4373677          11  both                 NaT         False          1       1
# 9005066          11  both          2014-03-21          True          0       1
# 7593917          11  both          2014-03-21          True          0       1
# 724172           11  both          2014-03-21          True          0       1
# 9225078           1  both                 NaT         False          1       1
# 7210256           1  both                 NaT         False          1       1
# 5311476           7  both                 NaT         False          1       1
# 487517            3  both                 NaT         False          1       1
# 487516            3  both          2014-05-30          True          0       1
# 487515            3  both          2014-05-30          True          0       1
# 487518            3  both          2014-05-30          True          0       1
# 487512            3  both          2014-05-30          True          0       1
# 487513            3  both          2014-05-30          True          0       1
# 9324781           0  both          2014-05-30          True          0       1
# 4414697           0  both          2014-06-02          True          0       1
# 8753189           0  both          2014-06-02          True          0       1
# 4246557           0  both          2014-06-02         False          1       2
# 596682            1  both          2014-10-06          True          0       2
# 596683            1  both          2014-10-09          True          0       2
# 596681            1  both          2014-10-09          True          0       2
# 596680            1  both          2014-10-09          True          0       2
# 596684            1  both          2014-10-09          True          0       2
# 596685            1  both          2014-10-09          True          0       2
# 1891193           3  both                 NaT         False          1       1
# 5384165           2  both          2014-05-31          True          0       1
# 3586524          -5  both          2014-05-31          True          0       1
# 7318246           3  both                 NaT         False          1       1
# 6598028           4  both                 NaT         False          1       1
# 10741215          0  both                 NaT         False          1       1
# 205066            2  both                 NaT         False          1       1
# 2743704           2  both          2014-06-04          True          0       1
# 8651188           1  both                 NaT         False          1       1
# 4734684           1  both          2014-01-16          True          0       1
# 7009106           1  both          2014-01-16         False          1       2
# 3013318           0  both                 NaT         False          1       1
# 3685662          -2  both                 NaT         False          1       1
# 1056425           0  both                 NaT         False          1       1
# 9340053           1  both          2014-06-19          True          0       1
# 9340054           1  both          2014-06-23          True          0       1
# 6948524          12  both          2014-06-23         False          1       2
# 8683233           1  both                 NaT         False          1       1
# 9009749           2  both          2014-02-14         False          1       2
#
# [50 rows x 29 columns]

# %% [markdown]
# ** Explore what voyages looks like for one vessel **

# %%
#look for a vessel with a lot of voyages and get the number of voyages per vessel and sort by number of voyages
df_v_LA[['vessel_name','voyage']].groupby('vessel_name').max().sort_values('voyage',ascending = False)
# Out:
#                        voyage
# vessel_name
# MAERSK WINNIPEG            13
# MOL MANEUVER               13
# APL THAILAND               13
# MAERSK WOLFSBURG           13
# ESTHER SCHULTE             12
# YM MASCULINITY             12
# YM MOVEMENT                11
# MOL MAGNIFICENCE           11
# HAMMONIA ROMA              11
# MOL MISSION                11
# APL ENGLAND                10
# SPRING R                   10
# CAP PALLISER               10
# XIN MEI ZHOU               10
# APL PHILIPPINES            10
# APL SINGAPORE              10
# HANJIN CONSTANTZA          10
# NYK FLORESTA               10
# SEA-LAND LIGHTNING         10
# XIN DA YANG ZHOU           10
# MOL MODERN                 10
# MOL MOTIVATOR               9
# SL CHARGER                  9
# NYK THESEUS                 9
# MOL MATRIX                  9
# HANJIN CHONGQING            9
# YM MODESTY                  9
# RJ PFEIFFER                 9
# SEALAND INTREPID            9
# SEALAND LIGHTNING           9
# ...                       ...
# HANJIN DUESSELDORF          1
# HANJIN COSTANZA             1
# HANJIN CHONQING             1
# HANJIN CHONGING             1
# HANJIN BRUSSEL              1
# HANJIN BERLIN               1
# HANJIN BEIJING              1
# HANJIN BALTIMORE            1
# HANJIN ATLANTA              1
# HANJIN ATHENS               1
# HANJIN ARGENTINA            1
# HANJIN INDONESIA            1
# HANJIN KINGSTON             1
# HANJIN LISBON               1
# HANJIN PORT KELAND          1
# HANJIN SCARLET              1
# HANJIN ROME                 1
# HANJIN RIO DE JANEIRO       1
# HANJIN PORTLAND             1
# HANJIN PORTKLANG            1
# HANJIN PORTKELANG           1
# HANJIN PARIS                1
# HANJIN MALTA                1
# HANJIN OTTAWA               1
# HANJIN NEWPORT              1
# HANJIN NEW JERSEY 00        1
# HANJIN NETHERLAND           1
# HANJIN MONACO               1
# HANJIN MARSEILLES           1
# ZIN YA ZHOU                 1
#
# [1640 rows x 1 columns]

# %%
#check that there are other ports besides LA in the new dataframe
df_v_LA.port_of_unlading.unique()
# Out:
# [Los Angeles, California, Seattle, Washington, Oakland, California, Long Beach, California, Los Angeles International Airport, Los Angeles..., ..., Brunswick, Georgia, San Francisco International Airport, San Franc..., Port San Luis, California, Omaha, Nebraska, Buffalo Niagara Falls, New York]
# Length: 119
# 4402205        6             2014-05-14          2014-05-14           0
# 4832652        7             2014-06-11          2014-06-11           0
# 4147798        7             2014-06-11          2014-06-11           0
# 1049408        7             2014-06-11          2014-06-11           0
# 9615389        7             2014-06-11          2014-06-11           0
# 9331599        7             2014-06-11          2014-06-11           0
# 6510993        7             2014-06-11          2014-06-11           0
# 3592466        7             2014-06-11          2014-06-11           0
# 4442197        8             2014-07-09          2014-07-09           0
# 3610730        8             2014-07-09          2014-07-09           0
# 2515596        8             2014-07-09          2014-07-24          15
# 10477592       8             2014-07-09          2014-07-09           0
# 7374906        8             2014-07-09          2014-07-09           0
# 514093         8             2014-07-09          2014-07-09           0
# 8494731        8             2014-07-09          2014-07-09           0
# 4442200        8             2014-07-09          2014-07-09           0
# 10225451       9             2014-08-06          2014-08-06           0
# 2220967        9             2014-08-04          2014-08-06           2
# 5744029        9             2014-08-06          2014-08-06           0
# 3911294        9             2014-08-06          2014-08-06           0
# 3348226        9             2014-08-06          2014-08-06           0
# 5200861       10             2014-09-03          2014-09-03           0

# %% [markdown]
# ** Delay Range by Voyage **
# look at the ranges around delays by voyage - look at examples that have a wide range

# %%
#get min and max delay by vessel name and voyage
delay_by_voyage = df_v_LA[['vessel_name','voyage','delay_days']].groupby(['vessel_name','voyage'],as_index=False).agg([min,max])

# %%
#reformat columns
delay_by_voyage.columns = ['_'.join(tup).rstrip('_') for tup in delay_by_voyage.columns.values]
delay_by_voyage.reset_index(col_level=1,inplace = True)
delay_by_voyage.head()
# Out:
#       vessel_name  voyage  delay_days_min  delay_days_max
# 0   GUSTAV MAERSK       1               1               1
# 1     XIN YA ZHOU       1               2               2
# 2            1406       1              14              14
# 3    610140003896       1               2               2
# 4         9074389       1               2               2

# %%
#add a delay difference column
delay_by_voyage['delay_diff'] = delay_by_voyage.delay_days_max - delay_by_voyage.delay_days_min

# %%
#view shape
delay_by_voyage.shape
# Out:
# (3755, 5)

# %%
#see number of rows where the difference between the min and max is greater than 5 days
delay_by_voyage[delay_by_voyage.delay_diff >= 5].shape
# Out:
# (2202, 5)

# %%
#look at some of the large discrepancies
delay_by_voyage.sort_values('delay_diff', ascending = False).head()
# Out:
#           vessel_name  voyage  delay_days_min  delay_days_max  delay_diff
# 2723      NYK PEGASUS       6            -724              15         739
# 2769      NYK THESEUS       6            -559               5         564
# 3024      SANTA PAOLA       2            -525               7         532
# 2870  OOCL LONG BEACH       2            -467              28         495
# 878       COSCO KOREA       8            -460              30         490

# %%
delay_by_voyage[delay_by_voyage.vessel_name == 'NYK PEGASUS']
# Out:
#       vessel_name  voyage  delay_days_min  delay_days_max  delay_diff
# 2718  NYK PEGASUS       1             732             733           1
# 2719  NYK PEGASUS       2               6             370         364
# 2720  NYK PEGASUS       3               0               0           0
# 2721  NYK PEGASUS       4              15              15           0
# 2722  NYK PEGASUS       5              -8              11          19
# 2723  NYK PEGASUS       6            -724              15         739
# 2724  NYK PEGASUS       7             -13              11          24
# 2725  NYK PEGASUS       8             -11               5          16

# %%
#view one of the vessels - unique records only
vessel2 = df_v_LA[df_v_LA.vessel_name == 'NYK PEGASUS'][['vessel_name','foreign_port_of_lading','port_of_unlading',
                                                             'voyage','estimated_arrival_date','actual_arrival_date',
                                                            'delay_days']].drop_duplicates()

# %%
#check the number of records
vessel2.shape
# Out:
# (258, 7)

# %% [markdown]
# Observations on vessel 2:
# - voyage 1: the actual arrival date and estimted arrival dates appear to have errors in the year: possible rule - change year of estimated arrival date if year is greater than 2014 and month and day are the same - the arrival is on time if years are changed.
# - voyage 2: is probably the same as voyage 1 - has similar issues, the years appear to be wrong: possibly change all non-2014 years to 2014 except december 2013 estimated arrival dates
# - Combine port of Los Angeles and port of Long Beach  (like we did with NY and Newark) - and add a column that combines these as one
# - Chicago appears in the list and this is clearly a mistake - need to identify west coast vs east coast ports and either modify the entry to make it the correct port or delete these reccords if there aren't very many
# - appears that in this case ships go to LA first and then to Oakland, which means oakland wouldn't be a stop along the way to LA
# - Voyage 3: is probably part of a later voyage, once year is changed to 2014
# - Voyage 4??? dates are from late in 2013 - not sure if this is an error or should be 2014
# - Voyage 5: texas and east coast ports are showing up in the list see fourth bullet
# - Voyage 6: there is both a 02-16 and a 02-03 arrival into LA - this doesn't make sense... the 02-16 would sync up with voyage 1  - the 02-03 appears to be wrong, but not sure how to fix this systematically - the 03-29 is a new voyage, but there is a 03-03 and 03-18 in the estimated arrival date that is causing it to be lumped into 6   - solution might be to check if there are estimated_arrival_date that are unique for the vessel, and drop there aren't very many or adjust them to the next lower estimated_arrival_date - possible they aren't actually unique though since I'm only showing a drop duplicates view...
# - voyage 7 - looks ok
# - keep only Los Angeles and Long Beach as port_of_unlading but check how many observations have non-west coast ports.

# %%
vessel2[250:258]
# Out:
#           vessel_name      foreign_port_of_lading  \
# 9621807   NYK PEGASUS  Shanghai ,China (Mainland)
# 10464317  NYK PEGASUS  Shanghai ,China (Mainland)
# 9337768   NYK PEGASUS  Shanghai ,China (Mainland)
# 8765823   NYK PEGASUS  Shanghai ,China (Mainland)
# 1622462   NYK PEGASUS  Shanghai ,China (Mainland)
# 6798565   NYK PEGASUS  Shanghai ,China (Mainland)
# 1344891   NYK PEGASUS  Shanghai ,China (Mainland)
# 9337818   NYK PEGASUS  Shanghai ,China (Mainland)
#
#                           port_of_unlading  voyage estimated_arrival_date  \
# 9621807            Los Angeles, California       8             2014-06-26
# 10464317           Los Angeles, California       8             2014-06-27
# 9337768            Los Angeles, California       8             2014-06-28
# 8765823                  Chicago, Illinois       8             2014-06-29
# 1622462   Dallas/Ft. Worth Airport, Texas        8             2014-06-29
# 6798565             Long Beach, California       8             2014-06-29
# 1344891            Los Angeles, California       8             2014-06-30
# 9337818            Los Angeles, California       8             2014-07-01
#
#          actual_arrival_date  delay_days
# 9621807           2014-06-20          -6
# 10464317          2014-06-20          -7
# 9337768           2014-06-20          -8
# 8765823           2014-06-20          -9
# 1622462           2014-06-20          -9
# 6798565           2014-06-20          -9
# 1344891           2014-06-20         -10
# 9337818           2014-06-20         -11
